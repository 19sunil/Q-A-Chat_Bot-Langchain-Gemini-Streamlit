# %% [markdown]
# <a href="https://colab.research.google.com/github/19sunil/Q-A-Chat_Bot-Langchain-Gemini-Streamlit/blob/repo11/Q%26A_Bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile app.py
from langchain_google_genai import ChatGoogleGenerativeAI
import streamlit as st

llm = ChatGoogleGenerativeAI(model = "gemini-2.5-flash")

st.title("|| Q_Buddy Chat_Bot ||")
st.markdown(" My Q&A ChatBot Using with Langchain, Google Gemini and nGrok. ")

if "messages" not in st.session_state:
  st.session_state.messages = []

for message in st.session_state.messages:
  role = message["role"]
  content = message["content"]
  st.chat_message(role).markdown(content)

query = st.chat_input("Ask me anything !!")
if query:
  st.session_state.messages.append({"role":"USER", "content": query})
  st.chat_message("USER").markdown(query)
  res = llm.invoke(query)
  st.chat_message("AI").markdown(res.content)
  st.session_state.messages.append({"role":"AI", "content": res.content})
# Out:
# Overwriting app.py

# %%
from pyngrok import ngrok

ngrok.set_auth_token("38QYx8lQOVHc0xIiA7ShbnEdDR3_59ksqAVWfN2HrbDw9mHVG")

# %%
import time
from pyngrok import ngrok

# Kill existing Streamlit
# !killall streamlit &>/dev/null

# Start Streamlit in background
# !nohup streamlit run app.py \
    --server.port 8501 \
    --server.address 0.0.0.0 \
    --server.headless true \
    --browser.gatherUsageStats false \
    > streamlit.log 2>&1 &

# Wait for Streamlit to boot
time.sleep(8)

# Start ngrok tunnel
public_url = ngrok.connect(8501)
print("🚀 Streamlit App URL:", public_url)
# Out:
# 🚀 Streamlit App URL: NgrokTunnel: "https://archiepiscopally-intercolumnar-margarito.ngrok-free.dev" -> "http://localhost:8501"
