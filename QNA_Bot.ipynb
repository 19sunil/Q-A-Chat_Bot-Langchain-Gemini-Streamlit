# %% [markdown]
# <a href="https://colab.research.google.com/github/19sunil/Q-A-Chat_Bot-Langchain-Gemini-Streamlit/blob/repo11/QNA_Bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile app.py
# from google.colab import userdata
import os
import streamlit as st
from langchain_google_genai import ChatGoogleGenerativeAI

# Load API key
# os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")

# LLM
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash",
                            temperature=0.3,
                            max_output_tokens=256)

# UI
st.title("🤖 Chat_Bot")
st.markdown("My QNA Chat Bot with LangChain, Google Gemini and nGrok !!")

# Chat memory
if "messages" not in st.session_state:
    st.session_state.messages = []

for message in st.session_state.messages:
    with st.chat_message(message["role"]):
        st.markdown(message["content"])

query = st.chat_input("Ask your question")
if query:
    st.session_state.messages.append({"role": "user", "content": query})
    with st.chat_message("user"):
        st.markdown(query)

    res = llm.invoke(query)

    with st.chat_message("ai"):
        st.markdown(res.content)

    st.session_state.messages.append(
        {"role": "ai", "content": res.content}
    )
# Out:
# Overwriting app.py

# %%
from pyngrok import ngrok

ngrok.set_auth_token("38NP0oN99cJnzjdQ0V36RF2mF2S_5ZduWwVEfwNUoFTdFU2kL")

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8501)
print("OPEN THIS LINK 👉", public_url)
# Out:
# OPEN THIS LINK 👉 NgrokTunnel: "https://archiepiscopally-intercolumnar-margarito.ngrok-free.dev" -> "http://localhost:8501"
